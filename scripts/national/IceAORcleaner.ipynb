# %%
import pandas as pd
import numpy as np
import re

##This file is needed to alter the AOR Cleaner such that it can be useful in serving as a pathway
##Between hotline data and ICE data

# %%
us_states = [
    # Multi-word states first to prevent partial matches
    "New Hampshire", "New Jersey", "New Mexico", "New York",
    "North Carolina", "North Dakota",
    "South Carolina", "South Dakota",
    "West Virginia",
    "Rhode Island",
    # Single-word states
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado",
    "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho",
    "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
    "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota",
    "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada",
    "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Tennessee", "Texas",
    "Utah", "Vermont", "Virginia", "Washington", "Wisconsin", "Wyoming"
]

# %%
AORdata_df = pd.read_csv("C:/Users/Jesse/OneDrive/Desktop/QSS20_WI26/Final Project/ice-offices(Sheet1).csv", encoding='latin-1')

df_filtered = AORdata_df[AORdata_df["office_name"].str.contains("Field Office", na=False, case=False)]

df_filtered["area"] = df_filtered["area"].str.split(", ")

pattern = r'\b(' + '|'.join(us_states) + r')\b'

df_filtered["state"] = df_filtered["area"].str.findall(pattern)

df_filtered.head(n=10)
# Out:
# C:\Users\Jesse\AppData\Local\Temp\ipykernel_24480\4273878369.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["area"] = df_filtered["area"].str.split(", ")
# C:\Users\Jesse\AppData\Local\Temp\ipykernel_24480\4273878369.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["state"] = df_filtered["area"].str.findall(pattern)
#                 office_name office_name_short agency field_office_name  \
# ...

# %%
df_final = df_filtered[["office_name", "office_name_short", "area"]]
df_final.to_csv("manualdatacleanneeded.csv", index=False) ##Further cleaning done by hand to account for certain geographic bounds
